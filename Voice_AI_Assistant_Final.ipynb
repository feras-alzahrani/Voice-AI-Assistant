# %%
# !pip install -q openai gTTS ipython
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 40.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# wandb 0.28.0 requires click>=8.2.0, but you have click 8.1.8 which is incompatible.
# huggingface-hub 1.23.0 requires click<9.0.0,>=8.4.2, but you have click 8.1.8 which is incompatible.

# %%
from openai import OpenAI
from gtts import gTTS
from IPython.display import Audio, display

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
# !pip install -q cohere
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.6/362.6 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 54.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.2/119.2 kB 8.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gtts 2.5.4 requires click<8.2,>=7.1, but you have click 8.4.2 which is incompatible.

# %%
import cohere

API_KEY = "cohere_SFFAHhv2Eukv26iueYvJMtCbn3zA6n4tdhA7vP3E0lvdtY"

co = cohere.Client(API_KEY)

print("✅ Cohere connected successfully!")
# Out:
# ✅ Cohere connected successfully!

# %%
import whisper

model = whisper.load_model("medium")

result = model.transcribe(
    "test.mp4",
    language="ar",
    task="transcribe"
)

user_text = result["text"].strip()

print("النص المستخرج:")
print(user_text)
# Out:
# /usr/local/lib/python3.12/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# النص المستخرج:
# كيف حالك؟

# %%
response = co.chat(
    message=user_text
)

ai_response = response.text

print("رد المساعد:")
print(ai_response)
# Out:
# رد المساعد:
# أنا بخير، شكراً لسؤالك! أنا مساعد ذكاء اصطناعي، لذا لا أمتلك مشاعر أو حالة صحية بالمعنى التقليدي، لكنني جاهز ومستعد للمساعدة وتقديم المعلومات والإجابات على أسئلتك. كيف يمكنني مساعدتك اليوم؟ هل لديك أي استفسارات أو مواضيع تود مناقشتها؟

# %%
from gtts import gTTS
from IPython.display import Audio, display

tts = gTTS(text=ai_response, lang="ar")

tts.save("response.mp3")

display(Audio("response.mp3", autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
